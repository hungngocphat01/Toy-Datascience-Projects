# %%
using LinearAlgebra
using Plots
using Statistics
using DataFrames
using Printf
using CSV

# %%
train_df = DataFrame(CSV.File("cubic_regression.csv"));
first(train_df, 5)
# Out:
# 5×2 DataFrame
#  Row │ x         y
#      │ Float64   Float64
# ─────┼────────────────────
#    1 │ -2.0527   -23.5795
#    2 │ -2.70287  -21.9686
#    3 │ -2.86447  -23.9116
#    4 │ -2.29218  -23.8335
#    5 │ -2.85833  -21.3365

# %%
describe(train_df)
# Out:
# 2×7 DataFrame
#  Row │ variable  mean      min        median   max       nmissing  eltype
#      │ Symbol    Float64   Float64    Float64  Float64   Int64     DataType
# ─────┼──────────────────────────────────────────────────────────────────────
#    1 │ x          1.49578   -2.99881   1.5668   5.96679         0  Float64
#    2 │ y         15.4401   -23.9116   17.0611  29.6062          0  Float64

# %%
train_df = dropmissing(train_df)
describe(train_df)
# Out:
# 2×7 DataFrame
#  Row │ variable  mean     min       median   max      nmissing  eltype
#      │ Symbol    Float64  Float64   Float64  Float64  Int64     DataType
# ─────┼───────────────────────────────────────────────────────────────────
#    1 │ x         50.0143   0.0       49.0    100.0           0  Float64
#    2 │ y         49.9399  -3.83998   48.973  108.872         0  Float64

# %%
X = train_df[:, :x];
Y_train = train_df[:, :y];
m = size(X, 1);
println("Shape of X_train:", size(X));
println("Shape of Y_train:", size(Y_train));
# Out:
# Shape of X_train:(500,)
# Shape of Y_train:(500,)

# %%
scatter(X, Y_train)

# %% [markdown]
# # Linear regression model
# Prediction:
# $$
# \mathbf{x} \in (f, 1) \\
# \mathbf{w} \in (f, 1) \\
# \mathbf{b} \in (1, 1) \ \text{(broadcasts to \( (m, 1) \))} \\
# \hat{y} = \mathbf{w}^T \mathbf{x} + \mathbf{b} \in (1, 1) \\
# \hat{\YY} = \mathbf{X}\mathbf{w} + \mathbf{b} \in (m, 1) \\
# $$
# Where
# $$
# \mathbf{X} = \begin{pmatrix}
#     - \mathbf{x}^{(1)T} - \\
#     - \mathbf{x}^{(2)T} - \\
#     - \mathbf{x}^{(3)T} - \\
#     \vdots \\
#     - \mathbf{x}^{(m)T} - \\
# \end{pmatrix} \in (m, f)
# $$
#
# Loss function:
# $$
# L = \frac{1}{2m} \sum_{i=0}^{m} (\mathbf{w}^T\mathbf{x}^{(i)} + b - y^{(i)})^2
#   = \frac{1}{2m} (\mathbf{X}\mathbf{w} + \mathbf{b} - \YY)^2 \\
# \Rightarrow \frac{dL}{d\mathbf{w}} = \frac{1}{m} \sum^{m}_{i=0} (\mathbf{w}^T\mathbf{x}^{(i)} + b - y^{(i)}) \cdot \mathbf{x}
#  = \frac{1}{m} \mathbf{X}^T (\mathbf{X}\mathbf{w} + \mathbf{b} - \YY) \in (f, 1) \\
# \frac{dL}{d\mathbf{b}} = \frac{1}{m} \sum^{m}_{i=0} (\mathbf{w}^T\mathbf{x}^{(i)} + b - y^{(i)})
#  = sum\left( \frac{1}{m} (\mathbf{X}\mathbf{w} + \mathbf{b} - \YY) \right) = sum\left( \frac{1}{m} (\hat{\YY} - \YY) \right) \in (1, 1)
# $$

# %%
function random_init(n_features)
    return rand(n_features, 1);
end
# Out:
# random_init (generic function with 1 method)

# %%
function cost_function(X, Y, parameters)
    w = parameters["w"];
    b = parameters["b"];
    
    cost = 1/(2*m) * sum((X*w .+ b - Y).^2);
    dw = 1/m * X' * (X*w .+ b - Y);
    db = 1/m * sum(X*w .+ b - Y);
    
    grad = Dict("dw" => dw, "db" => db);
    return cost, grad;
end
# Out:
# cost_function (generic function with 1 method)

# %%
function gradient_checking(X, Y)
    n_features = size(X, 2);
    w_check = random_init(n_features);
    b_check = rand();
    parameters = Dict("w" => w_check, "b" => b_check);
    
    cost, grad = cost_function(X, Y, parameters);
    dw = grad["dw"];
    db = grad["db"];
    
    epsilon = 1e-5;
    dw_approx = Float64[];
    for i = 1:n_features
        epsilon_vector = zeros(n_features);
        epsilon_vector[i] = epsilon;
        
        params_w_plus = Dict("w" => w_check + epsilon_vector, "b" => b_check);
        params_w_minus = Dict("w" => w_check - epsilon_vector, "b" => b_check);
        
        cost_w_plus, _ = cost_function(X, Y, params_w_plus);
        cost_w_minus, _ = cost_function(X, Y, params_w_minus);
        
        dw_approx_i = (cost_w_plus - cost_w_minus) / (2*epsilon);
        push!(dw_approx, dw_approx_i);
    end
    
    params_b_minus = Dict("w" => w_check, "b" => b_check - epsilon);
    params_b_plus  = Dict("w" => w_check, "b" => b_check + epsilon);
    
    cost_b_plus, _ = cost_function(X, Y, params_b_plus);
    cost_b_minus, _ = cost_function(X, Y, params_b_minus);
    
    db_approx = (cost_b_plus - cost_b_minus) / (2*epsilon);
        
    println("dw = ", dw);
    println("dw_approx = ", dw_approx);
    println("db = ", db);
    println("db_approx = ", db_approx);
end
# Out:
# gradient_checking (generic function with 1 method)

# %%
function gradient_descent(X, Y, params, cost_func, lr=0.01, max_iters=1000)
    w = copy(params["w"]);
    b = copy(params["b"]);
    
    costs = [];
    for i = 1:max_iters
        cost, grad = cost_func(X, Y, params);
        
        dw = grad["dw"];
        db = grad["db"];
        
        w = w - lr .* dw;
        b = b - lr * db;
        params = Dict("w" => w, "b" => b);
        
        push!(costs, cost);
        if i % 100 == 0
            println("Iter ", i, "/", max_iters, ": cost = ", cost);
        end
    end;
    
    return Dict("w" => w, "b" => b), costs;
end
# Out:
# gradient_descent (generic function with 3 methods)

# %%
gradient_checking(X, Y_train)
# Out:
# dw = [-3.0407566697864343]
# dw_approx = [-3.0407566711687646]
# db = -14.85016691914954
# db_approx = -14.85016692015506

# %%
function predict(X, parameters)
    w = parameters["w"];
    b = parameters["b"];
    return X*w .+ b;
end
# Out:
# predict (generic function with 1 method)

# %%
function fit(X, Y, lr=0.01, max_iters=1000)
    n_features = size(X, 2);
    w = random_init(n_features);
    b = 1;
    
    params = Dict("w" => w, "b" => b);
    
    learned_params, costs = gradient_descent(X, Y, params, cost_function, lr, max_iters);
    
    return learned_params, costs;
end;

# %%
function scale(X)    
    # Loop each column 
    for i = 1:size(X, 2)
        col = X[:, i];
        col_std = std(col);
        col_mean = mean(col);
        
        X[:, i] = (col .- col_mean)./col_std;
    end
    return X
end
# Out:
# scale (generic function with 1 method)

# %%
scale(X);
scale(Y_train);

# %%
function generate_poly_features(X, poly)
    new_features = copy(X);
    for i = 2:poly
        feature = X.^i;
        new_features = hcat(new_features, feature);
    end
    return new_features;
end
# Out:
# generate_poly_features (generic function with 1 method)

# %%
n_poly = 3;
X_train  = generate_poly_features(X, n_poly)
# Out:
# 500×3 Matrix{Float64}:
#  -1.48006  2.19059  -3.2422
#  -1.75125  3.06686  -5.37084
#  -1.81865  3.30748  -6.01514
#  -1.57995  2.49623  -3.9439
#  -1.81609  3.29817  -5.98977
#  -1.87468  3.51443  -6.58843
#  -1.81273  3.28599  -5.95661
#  -1.70306  2.90043  -4.93962
#  -1.84763  3.41373  -6.3073
#  -1.64633  2.7104   -4.46222
#  -1.71629  2.94566  -5.05562
#  -1.72592  2.97879  -5.14114
#  -1.78045  3.17001  -5.64404
#   ⋮
#   1.80804  3.26902   5.91052
#   1.39789  1.95408   2.73159
#   1.82565  3.33299   6.08486
#   1.62575  2.64305   4.29693
#   1.81034  3.27734   5.93311
#   1.63812  2.68344   4.39579
#   1.65564  2.74114   4.53834
#   1.53658  2.36106   3.62795
#   1.69498  2.87296   4.86961
#   1.7777   3.16022   5.61793
#   1.58664  2.51744   3.99428
#   1.86484  3.47764   6.48526

# %%
lr=0.1;
max_iters=150;
learned_params, costs = fit(X_train, Y_train, lr, max_iters);
plot(1:max_iters, costs)
# Out:
# Iter 100/150: cost = 0.0829752269234539

# %%
# Draw regresison line 
x_min = minimum(X_train[:, 1]);
x_max = maximum(X_train[:, 1]);
plot_x_range = generate_poly_features(LinRange(x_min, x_max, 100), n_poly);

w = learned_params["w"];
b = learned_params["b"];

y_reg = plot_x_range * w .+ b;

# %%
p = scatter(X_train[:, 1], Y_train);
plot!(p, plot_x_range[:, 1], y_reg, lw=5)

# %%
w, b
# Out:
# ([-0.9003624036187652; -0.5454777843243791; 0.6880183035844682], 0.5579724391451307)
